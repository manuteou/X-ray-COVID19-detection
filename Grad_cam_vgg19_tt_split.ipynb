# %% [markdown]
# ---
# <h1><font color=red><strong><div align="center">COVID DETECTION <strong></font><h1></div>
# <div align="center"><img src="https://media.lactualite.com/2020/03/b93f0a42-2871.jpg" alt="drawing" width="300"/>
#
# ---

# %% [markdown]
# *The aim of this model is to give COVID's prediction case, to help for diagnostic.*<br>
# *The prediction will be given from medical radio.*<br>
# *The dataset is from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database*<br>
# *he is divised in 3 categories:*<br>
# * Normal radio
# * Viral Peumonia radio
# * COVID radio

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image_dataset_from_directory
import matplotlib.cm as cm
from IPython.display import Image
import pandas as pd
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)
tf.config.experimental.set_memory_growth(gpu[1], True)

# %% [markdown]
# # LOADING AND PREPROCESSING DATA

# %%
import pathlib
train_folder = pathlib.Path("../files2")
train_folder
# Out:
# WindowsPath('../files2')

# %%
all_image_paths = [str(img_path) for img_path in list(train_folder.glob("*/*.png"))]
all_image_paths[-5:]
# Out:
# ['..\\files2\\Viral Pneumonia\\Viral Pneumonia (995).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (996).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (997).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (998).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (999).png']

# %%
len(all_image_paths) # number of images total
# Out:
# 3361

# %%
df = pd.DataFrame(all_image_paths)
df = df.rename(columns={0:'X'})
df.head()
# Out:
#                                   X
# 0     ..\files2\COVID\COVID (1).png
# 1    ..\files2\COVID\COVID (10).png
# 2   ..\files2\COVID\COVID (100).png
# 3  ..\files2\COVID\COVID (1000).png
# 4  ..\files2\COVID\COVID (1001).png

# %%
labels = []
for label in train_folder.iterdir():
  labels += [label.name]
  
labels
# Out:
# ['COVID', 'NORMAL', 'Viral Pneumonia']

# %%
label_index = {}

for i, label in enumerate(labels):
  label_index[label]= i

  
label_index
# Out:
# {'COVID': 0, 'NORMAL': 1, 'Viral Pneumonia': 2}

# %%
# Create lables for each image
all_image_labels = [label_index[path.parent.name] for path in list(train_folder.glob("*/*"))]

df['Y'] = all_image_labels
df.tail()
# Out:
#                                                       X  Y
# 3356  ..\files2\Viral Pneumonia\Viral Pneumonia (995...  2
# 3357  ..\files2\Viral Pneumonia\Viral Pneumonia (996...  2
# 3358  ..\files2\Viral Pneumonia\Viral Pneumonia (997...  2
# 3359  ..\files2\Viral Pneumonia\Viral Pneumonia (998...  2
# 3360  ..\files2\Viral Pneumonia\Viral Pneumonia (999...  2

# %%
df_shuffled=df.sample(frac=1).reset_index(drop=True)
display(df_shuffled.head())

print('\n')
print('\n')
print('Labels numbers :')
print('\n')
print(df_shuffled['Y'].value_counts())
# Out:
#                                   X  Y
# 0  ..\files2\COVID\COVID (1054).png  0
# 1   ..\files2\COVID\COVID (985).png  0
# 2   ..\files2\COVID\COVID (487).png  0
# 3   ..\files2\COVID\COVID (699).png  0
# 4   ..\files2\COVID\COVID (896).png  0
# Labels numbers :
#
#
# 1    1194
# 0    1100
# 2    1067
# Name: Y, dtype: int64

# %%
X = df_shuffled['X']
Y = df_shuffled['Y'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=0,stratify=Y)

train_tensor = tf.data.Dataset.from_tensor_slices((X_train))
validation_tensor = tf.data.Dataset.from_tensor_slices((X_test))

label_train = tf.data.Dataset.from_tensor_slices(y_train) 
label_val= tf.data.Dataset.from_tensor_slices(y_test)

# %%
def data_aug(img, label):

    img= tf.io.read_file(img)
    img = tf.image.decode_jpeg(img, channels=3)
    #img = tf.image.central_crop(img, central_fraction=0.7)
    img = tf.image.resize(img, [256, 256])
    img = tf.image.random_flip_left_right(img)
    #img = tf.image.random_contrast(img, 0.5, 0.7)
    img = tf.image.random_brightness(img, 0.05)
    #img = tf.image.random_crop(img, [256,256,3])
    img = img / 255

    return img, label

def load_and_preprocess_images(img):
    img = tf.io.read_file(img)
    img = tf.image.decode_jpeg(img, channels=3)
    #img = tf.image.central_crop(img, central_fraction=0.7)
    img = tf.image.resize(img, [256, 256])
    img = img / 255
    return img

# %%
train_data = tf.data.Dataset.zip((train_tensor, label_train))
repeated_train_data= train_data.repeat(2)
repeated_train_data= repeated_train_data.map(data_aug)

# %%
#train_tensor = train_tensor.map(load_and_preprocess_images)
#train_data = tf.data.Dataset.zip((train_tensor, label_train))

# %%
validation_tensor = validation_tensor.map(load_and_preprocess_images)
validation_data = tf.data.Dataset.zip((validation_tensor, label_val))

# %%
print('size of train set is {} total images'.format(len(repeated_train_data)))
print('size of validation set is {} images total'.format(len(validation_data)))
# Out:
# size of train set is 4704 total images
# size of validation set is 1009 images total

# %%
repeated_train_data = repeated_train_data.shuffle(len(repeated_train_data)).batch(10)
validation_data = validation_data.batch(10)

# %%
#train_data = train_data.shuffle(len(train_data)).batch(16)
#validation_data = validation_data.batch(16)

# %%
for tensor,label in repeated_train_data.take(1):
#for tensor,label in train_data.take(1):
    print (tensor)
    print(label)
# Out:
# tf.Tensor(
# [[[[0.1255517  0.1255517  0.1255517 ]
#    [0.12222754 0.12222754 0.12222754]
#    [0.12455598 0.12455598 0.12455598]
#    ...
#    [0.1157784  0.1157784  0.1157784 ]
#    [0.12163012 0.12163012 0.12163012]
#    [0.12163012 0.12163012 0.12163012]]
#
#   [[0.11816811 0.11816811 0.11816811]
#    [0.11797334 0.11797334 0.11797334]
#    [0.12086419 0.12086419 0.12086419]
#    ...
#    [0.12316198 0.12316198 0.12316198]
#    [0.1290137  0.1290137  0.1290137 ]
#    [0.1290137  0.1290137  0.1290137 ]]
#
#   [[0.15663318 0.15663318 0.15663318]
#    [0.15663318 0.15663318 0.15663318]
#    [0.15427878 0.15427878 0.15427878]
#    ...
#    [0.12805863 0.12805863 0.12805863]
#    [0.13655047 0.13655047 0.13655047]
#    [0.13655047 0.13655047 0.13655047]]
#
#   ...
#
#   [[0.367923   0.367923   0.367923  ]
#    [0.37619442 0.37619442 0.37619442]
#    [0.32587272 0.32587272 0.32587272]
#    ...
#    [0.28653514 0.28653514 0.28653514]
#    [0.2478403  0.2478403  0.2478403 ]
#    [0.22789544 0.22789544 0.22789544]]
#
#   [[0.35946712 0.35946712 0.35946712]
#    [0.38332045 0.38332045 0.38332045]
#    [0.34423387 0.34423387 0.34423387]
#    ...
#    [0.28892484 0.28892484 0.28892484]
#    [0.7114822  0.7114822  0.7114822 ]
#    [0.66521513 0.66521513 0.66521513]
#    ...
#    [0.4032015  0.4032015  0.4032015 ]
#    [0.40530527 0.40530527 0.40530527]
#    [0.41371334 0.41371334 0.41371334]]
#
#   ...
#
#   [[0.01433376 0.01433376 0.01433376]
#    [0.06558897 0.06558897 0.06558897]
#    [0.1286634  0.1286634  0.1286634 ]
#    ...
#    [0.33516082 0.33516082 0.33516082]
#    [0.20580314 0.20580314 0.20580314]
#    [0.16818547 0.16818547 0.16818547]]
#
#   [[0.00903259 0.00903259 0.00903259]
#    [0.07058506 0.07058506 0.07058506]
#    [0.11944786 0.11944786 0.11944786]
#    ...
#    [0.30971634 0.30971634 0.30971634]
#    [0.20743722 0.20743722 0.20743722]
#    [0.1694281  0.1694281  0.1694281 ]]
#
#   [[0.02190789 0.02190789 0.02190789]
#    [0.0685112  0.0685112  0.0685112 ]
#    [0.1270329  0.1270329  0.1270329 ]
#    ...
#    [0.2766715  0.2766715  0.2766715 ]
#    [0.19611494 0.19611494 0.19611494]
#    [0.17301218 0.17301218 0.17301218]]]
#
#
#  [[[0.31879893 0.31879893 0.31879893]
#    [0.32691976 0.32691976 0.32691976]
#    [0.33442247 0.33442247 0.33442247]
#    ...
#    [0.371321   0.371321   0.371321  ]
#    [0.36881244 0.36881244 0.36881244]
#    [0.37711784 0.37711784 0.37711784]]
#
#   [[0.3178424  0.3178424  0.3178424 ]
#    [0.32445306 0.32445306 0.32445306]
#    [0.3375317  0.3375317  0.3375317 ]
#    ...
#    [0.37175393 0.37175393 0.37175393]
#    [0.3859638  0.3859638  0.3859638 ]
#    [0.3910239  0.3910239  0.3910239 ]]
#
#   [[0.32579494 0.32579494 0.32579494]
#    [0.31889886 0.31889886 0.31889886]
#    [0.33075416 0.33075416 0.33075416]
#    ...
#    [0.38092846 0.38092846 0.38092846]
#    [0.38899502 0.38899502 0.38899502]
#    [0.39350733 0.39350733 0.39350733]]
#
#   ...
#
#   [[0.4921228  0.4921228  0.4921228 ]
#    [0.21097371 0.21097371 0.21097371]
#    [0.12436442 0.12436442 0.12436442]
#    ...
#    [0.22738218 0.22738218 0.22738218]
#    [0.16949853 0.16949853 0.16949853]
#    [0.128204   0.128204   0.128204  ]]
#
#   [[0.46835342 0.46835342 0.46835342]
#    [0.22723378 0.22723378 0.22723378]
#    [0.12702267 0.12702267 0.12702267]
#    ...
#    [0.23094693 0.23094693 0.23094693]
#    [0.17111842 0.17111842 0.17111842]
#    [0.13441445 0.13441445 0.13441445]]
#
#   [[0.45846632 0.45846632 0.45846632]
#    [0.2134274  0.2134274  0.2134274 ]
#    [0.11913358 0.11913358 0.11913358]
#    ...
#    [0.22366878 0.22366878 0.22366878]
#    [0.16845405 0.16845405 0.16845405]
#    [0.11992501 0.11992501 0.11992501]]]], shape=(10, 256, 256, 3), dtype=float32)
# tf.Tensor([0 2 0 2 2 1 0 0 1 1], shape=(10,), dtype=int64)

# %%
for tensor,label in validation_data.take(1):
    print (tensor)
    print(label)
# Out:
# tf.Tensor(
# [[[[0.6203968  0.6203968  0.6203968 ]
#    ...
#    [0.5734069  0.5734069  0.5734069 ]
#    [0.5646635  0.5646635  0.5646635 ]
#    [0.55386794 0.55386794 0.55386794]]
#
#   [[0.22930454 0.22930454 0.22930454]
#    [0.2604626  0.2604626  0.2604626 ]
#    [0.28563112 0.28563112 0.28563112]
#    ...
#    [0.56933975 0.56933975 0.56933975]
#    [0.5658471  0.5658471  0.5658471 ]
#    [0.5547947  0.5547947  0.5547947 ]]]], shape=(10, 256, 256, 3), dtype=float32)
# tf.Tensor([1 2 1 2 1 2 2 2 1 2], shape=(10,), dtype=int64)

# %%
def build_model_2():
    # we will use costum training with VGG19
    input_tensor = tf.keras.Input(shape=(256,256,3))
    VGG19 = tf.keras.applications.VGG19(input_shape=(256,256,3),include_top=False, input_tensor=input_tensor)
    VGG19.trainable = False # The VGG19 will use imagnet weight by default
    
    top_model = tf.keras.Sequential()
    top_model.add(tf.keras.layers.GlobalMaxPooling2D())
    top_model.add(tf.keras.layers.Dense(4096, activation=tf.nn.relu))
    top_model.add(tf.keras.layers.Dropout(0.3))
    top_model.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
    top_model.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
    top_model.add(tf.keras.layers.Dropout(0.1))
   
    top_model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))
    
    model = tf.keras.Model(inputs=VGG19.input, outputs=top_model(VGG19.output))
    
    model.compile(optimizer = 'Adam',
              loss= tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics = tf.keras.metrics.SparseCategoricalAccuracy())
    return model

# %%
model = build_model_2()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# sequential (Sequential)      (None, 3)                 4463107
# =================================================================
# Total params: 24,487,491
# Trainable params: 4,463,107
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
#model.fit(x=repeated_train_data, validation_data=validation_data, epochs=3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
# checkpoint will be use to save model each time performance are better
checkpoint = ModelCheckpoint("model_VGG19_3.h5", monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
#early stopping will stop training if the validation accuracy don't progress  
early = EarlyStopping(monitor='val_sparse_categorical_accuracy',min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(x=repeated_train_data, validation_data=validation_data, epochs=25, callbacks=[checkpoint,early])
# Out:
# Epoch 1/25
# 471/471 [==============================] - 71s 69ms/step - loss: 0.6689 - sparse_categorical_accuracy: 0.7154 - val_loss: 0.2552 - val_sparse_categorical_accuracy: 0.9138
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.91378, saving model to model_VGG19_3.h5
# Epoch 2/25
# 471/471 [==============================] - 64s 62ms/step - loss: 0.3027 - sparse_categorical_accuracy: 0.8891 - val_loss: 0.2710 - val_sparse_categorical_accuracy: 0.8949
#
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.91378
# Epoch 3/25
# 471/471 [==============================] - 65s 63ms/step - loss: 0.2975 - sparse_categorical_accuracy: 0.9003 - val_loss: 0.2335 - val_sparse_categorical_accuracy: 0.9167
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.91378 to 0.91675, saving model to model_VGG19_3.h5
# Epoch 4/25
# 471/471 [==============================] - 65s 63ms/step - loss: 0.2206 - sparse_categorical_accuracy: 0.9171 - val_loss: 0.3665 - val_sparse_categorical_accuracy: 0.8712
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.91675
# Epoch 5/25
# 471/471 [==============================] - 66s 64ms/step - loss: 0.2245 - sparse_categorical_accuracy: 0.9199 - val_loss: 0.2108 - val_sparse_categorical_accuracy: 0.9187
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.91675 to 0.91873, saving model to model_VGG19_3.h5
# Epoch 6/25
# 471/471 [==============================] - 68s 64ms/step - loss: 0.2252 - sparse_categorical_accuracy: 0.9122 - val_loss: 0.1845 - val_sparse_categorical_accuracy: 0.9336
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.91873 to 0.93360, saving model to model_VGG19_3.h5
# Epoch 7/25
# 471/471 [==============================] - 69s 65ms/step - loss: 0.2112 - sparse_categorical_accuracy: 0.9270 - val_loss: 0.1916 - val_sparse_categorical_accuracy: 0.9386
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.93360 to 0.93855, saving model to model_VGG19_3.h5
# Epoch 8/25
# 471/471 [==============================] - 71s 68ms/step - loss: 0.2079 - sparse_categorical_accuracy: 0.9280 - val_loss: 0.2108 - val_sparse_categorical_accuracy: 0.9306
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.93855
# Epoch 9/25
# 471/471 [==============================] - 72s 68ms/step - loss: 0.2014 - sparse_categorical_accuracy: 0.9256 - val_loss: 0.1959 - val_sparse_categorical_accuracy: 0.9316
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.93855
# Epoch 10/25
# 471/471 [==============================] - 73s 69ms/step - loss: 0.1900 - sparse_categorical_accuracy: 0.9356 - val_loss: 0.1708 - val_sparse_categorical_accuracy: 0.9415
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.93855 to 0.94153, saving model to model_VGG19_3.h5
# Epoch 11/25
# 471/471 [==============================] - 74s 69ms/step - loss: 0.1988 - sparse_categorical_accuracy: 0.9296 - val_loss: 0.2703 - val_sparse_categorical_accuracy: 0.9029
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.94153
# Epoch 12/25
# 471/471 [==============================] - 77s 72ms/step - loss: 0.1780 - sparse_categorical_accuracy: 0.9430 - val_loss: 0.1667 - val_sparse_categorical_accuracy: 0.9435
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.94153 to 0.94351, saving model to model_VGG19_3.h5
# Epoch 13/25
# 471/471 [==============================] - 77s 72ms/step - loss: 0.1860 - sparse_categorical_accuracy: 0.9333 - val_loss: 0.1864 - val_sparse_categorical_accuracy: 0.9405
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 14/25
# 471/471 [==============================] - 79s 72ms/step - loss: 0.1731 - sparse_categorical_accuracy: 0.9440 - val_loss: 0.1844 - val_sparse_categorical_accuracy: 0.9336
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 15/25
# 471/471 [==============================] - 80s 74ms/step - loss: 0.1569 - sparse_categorical_accuracy: 0.9435 - val_loss: 0.1662 - val_sparse_categorical_accuracy: 0.9415
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 16/25
# 471/471 [==============================] - 82s 76ms/step - loss: 0.1710 - sparse_categorical_accuracy: 0.9363 - val_loss: 0.1716 - val_sparse_categorical_accuracy: 0.9405 sparse_categoric
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 17/25
# 471/471 [==============================] - 84s 76ms/step - loss: 0.1612 - sparse_categorical_accuracy: 0.9417 - val_loss: 0.1578 - val_sparse_categorical_accuracy: 0.9415
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 18/25
# 471/471 [==============================] - 84s 76ms/step - loss: 0.1659 - sparse_categorical_accuracy: 0.9398 - val_loss: 0.2494 - val_sparse_categorical_accuracy: 0.9158
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 19/25
# 471/471 [==============================] - 86s 77ms/step - loss: 0.1739 - sparse_categorical_accuracy: 0.9410 - val_loss: 0.1602 - val_sparse_categorical_accuracy: 0.9386
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 20/25
# 471/471 [==============================] - 88s 78ms/step - loss: 0.1575 - sparse_categorical_accuracy: 0.9447 - val_loss: 0.1766 - val_sparse_categorical_accuracy: 0.9435
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 21/25
# 471/471 [==============================] - 90s 80ms/step - loss: 0.1713 - sparse_categorical_accuracy: 0.9401 - val_loss: 0.2156 - val_sparse_categorical_accuracy: 0.9277
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 22/25
# 471/471 [==============================] - 92s 82ms/step - loss: 0.1494 - sparse_categorical_accuracy: 0.9462 - val_loss: 0.2025 - val_sparse_categorical_accuracy: 0.9376
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.94351
# Epoch 23/25
# 471/471 [==============================] - 93s 83ms/step - loss: 0.1627 - sparse_categorical_accuracy: 0.9432 - val_loss: 0.1660 - val_sparse_categorical_accuracy: 0.9475
#
# Epoch 00023: val_sparse_categorical_accuracy improved from 0.94351 to 0.94747, saving model to model_VGG19_3.h5
# Epoch 24/25
# 471/471 [==============================] - 97s 86ms/step - loss: 0.1454 - sparse_categorical_accuracy: 0.9488 - val_loss: 0.1635 - val_sparse_categorical_accuracy: 0.9425
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.94747
# Epoch 25/25
# 471/471 [==============================] - 109s 99ms/step - loss: 0.1405 - sparse_categorical_accuracy: 0.9509 - val_loss: 0.2324 - val_sparse_categorical_accuracy: 0.9296
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.94747

# %% [markdown]
# ### The final accuracy for the model is 96% Epoch 20

# %%
loss_curve = history.history["loss"]
loss_val = history.history["val_loss"]
acc_curve = history.history["sparse_categorical_accuracy"]
acc_val = history.history["val_sparse_categorical_accuracy"]

plt.plot(loss_val,label="Loss_val")
plt.plot(loss_curve,label="Loss_train")
plt.legend()
plt.title("loss")
plt.show()

plt.plot(acc_val, label="acc_val" )
plt.plot(acc_curve, label="acc_train" )
plt.legend()
plt.title("accuracy")
plt.show()

# %% [markdown]
# # GRAD CAM

# %% [markdown]
# *We will use gradiant to visualize the model detection's result*

# %%
#for the prepocessing of image
img_size = (256, 256)
preprocess_input = tf.keras.applications.xception.preprocess_input

#we selected the last convolution layers
last_conv_layer_name = "block5_conv4"
classifier_layer_names = ["block5_pool","sequential"]

# %%
def get_img_array(img_path, size):
    
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=size)
    array = tf.keras.preprocessing.image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(
    img_array, model, last_conv_layer_name, classifier_layer_names
):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer
    last_conv_layer = model.get_layer(last_conv_layer_name)
    last_conv_layer_model = tf.keras.Model(model.inputs, last_conv_layer.output)

    # Second, we create a model that maps the activations of the last conv
    # layer to the final class predictions

    classifier_input = tf.keras.Input(shape=last_conv_layer.output.shape[1:])
    x = classifier_input
    for layer_name in classifier_layer_names:
        x = model.get_layer(layer_name)(x)
    classifier_model = tf.keras.Model(classifier_input, x)

    #classifier = model.get_layer(classifier_layer_names)
    #classifier_model = tf.keras.Model(classifier.input, classifier.output)

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        # Compute activations of the last conv layer and make the tape watch it
        last_conv_layer_output = last_conv_layer_model(img_array)
        tape.watch(last_conv_layer_output)
        # Compute class predictions
        preds = classifier_model(last_conv_layer_output)
        top_pred_index = tf.argmax(preds[0])
        top_class_channel = preds[:, top_pred_index]

    # This is the gradient of the top predicted class with regard to
    # the output feature map of the last conv layer
    grads = tape.gradient(top_class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        last_conv_layer_output[:, :, i] *= pooled_grads[i]

    # The channel-wise mean of the resulting feature map
    # is our heatmap of class activation
    heatmap = np.mean(last_conv_layer_output, axis=-1)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    return heatmap

# %%
import glob
from PIL import Image
covid = "../Images/Train/COVID/*"
pneumo = "../Images/Train/Viral Pneumonia/*"
normal = "../Images/Train/NORMAL/*"
path_covid = glob.glob(covid)[10]
path_pneumo = glob.glob(pneumo)[10]
path_normal = glob.glob(normal)[50]
img_covid = Image.open(glob.glob(covid)[10])
img_pneumo = Image.open(glob.glob(pneumo)[10])
img_normal = Image.open(glob.glob(normal)[10])

# %%
glob.glob(covid)[86]
# Out:
# '../Images/Train/COVID\\COVID (1086).png'

# %%
# Prepare image
img_array_c = preprocess_input(get_img_array(path_covid, size=img_size))
img_array_p = preprocess_input(get_img_array(path_pneumo, size=img_size))
img_array_n = preprocess_input(get_img_array(path_normal, size=img_size))

# Make model
model = tf.keras.models.load_model("model_VGG19_3.h5")
#9Generate class activation heatmap
heatmap_c = make_gradcam_heatmap(
    img_array_c, model, last_conv_layer_name, classifier_layer_names
)
heatmap_p = make_gradcam_heatmap(
    img_array_p, model, last_conv_layer_name, classifier_layer_names
)
heatmap_n = make_gradcam_heatmap(
    img_array_n, model, last_conv_layer_name, classifier_layer_names
)

# %%
def superpose(path, heatmap):
    # We load the original image
    img = tf.keras.preprocessing.image.load_img(path)
    img = tf.keras.preprocessing.image.img_to_array(img)
    # We rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)
    # We use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")
    # We use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]
    # We create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)
    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * 0.4 + img
    return  tf.keras.preprocessing.image.array_to_img(superimposed_img)
    
    

# Save the superimposed image
#save_path = "grad_cam_radio.jpg"
#superimposed_img.save(save_path)

# Display Grad CAM
#display(Image(save_path))
plt.figure(figsize=(20,20))

plt.subplot(2,3,1)
plt.imshow(superpose(path_covid,heatmap_c))
plt.title("COVID")

plt.subplot(2,3,2)
plt.imshow(superpose(path_pneumo,heatmap_p))
plt.title("Viral Pneumonia")

plt.subplot(2,3,3)
plt.imshow(superpose(path_normal,heatmap_n))
plt.title("Normal")

plt.subplot(2,3,4)
plt.imshow(img_covid,cmap='binary')
plt.title("COVID")

plt.subplot(2,3,5)
plt.imshow(img_pneumo,cmap='binary')
plt.title("Viral Pneumonia")

plt.subplot(2,3,6)
plt.imshow(img_normal,cmap='binary')
plt.title("Normal")

plt.show()
