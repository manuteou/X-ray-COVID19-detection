# %% [markdown]
# ---
# <h1><font color=red><strong><div align="center">COVID DETECTION <strong></font><h1></div>
# <div align="center"><img src="https://media.lactualite.com/2020/03/b93f0a42-2871.jpg" alt="drawing" width="300"/>
#
# ---

# %% [markdown]
# *The aim of this model is to give COVID's prediction case, to help for diagnostic.*<br>
# *The prediction will be given from medical radio.*<br>
# *The dataset is from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database*<br>
# *he is divised in 3 categories:*<br>
# * Normal radio
# * Viral Peumonia radio
# * COVID radio

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image_dataset_from_directory
import matplotlib.cm as cm
from IPython.display import Image
import pandas as pd
gpu = tf.config.experimental.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(gpu[0], True)
tf.config.experimental.set_memory_growth(gpu[1], True)

# %% [markdown]
# # LOADING AND PREPROCESSING DATA

# %%
import pathlib
train_folder = pathlib.Path("../files2")
train_folder
# Out:
# WindowsPath('../files2')

# %%
all_image_paths = [str(img_path) for img_path in list(train_folder.glob("*/*.png"))]
all_image_paths[-5:]
# Out:
# ['..\\files2\\Viral Pneumonia\\Viral Pneumonia (995).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (996).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (997).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (998).png',
#  '..\\files2\\Viral Pneumonia\\Viral Pneumonia (999).png']

# %%
len(all_image_paths) # number of images total
# Out:
# 3361

# %%
df = pd.DataFrame(all_image_paths)
df = df.rename(columns={0:'X'})
df.head()
# Out:
#                                   X
# 0     ..\files2\COVID\COVID (1).png
# 1    ..\files2\COVID\COVID (10).png
# 2   ..\files2\COVID\COVID (100).png
# 3  ..\files2\COVID\COVID (1000).png
# 4  ..\files2\COVID\COVID (1001).png

# %%
labels = []
for label in train_folder.iterdir():
  labels += [label.name]
  
labels
# Out:
# ['COVID', 'NORMAL', 'Viral Pneumonia']

# %%
label_index = {}

for i, label in enumerate(labels):
  label_index[label]= i

  
label_index
# Out:
# {'COVID': 0, 'NORMAL': 1, 'Viral Pneumonia': 2}

# %%
# Create lables for each image
all_image_labels = [label_index[path.parent.name] for path in list(train_folder.glob("*/*"))]

df['Y'] = all_image_labels
df.tail()
# Out:
#                                                       X  Y
# 3356  ..\files2\Viral Pneumonia\Viral Pneumonia (995...  2
# 3357  ..\files2\Viral Pneumonia\Viral Pneumonia (996...  2
# 3358  ..\files2\Viral Pneumonia\Viral Pneumonia (997...  2
# 3359  ..\files2\Viral Pneumonia\Viral Pneumonia (998...  2
# 3360  ..\files2\Viral Pneumonia\Viral Pneumonia (999...  2

# %%
df_shuffled=df.sample(frac=1).reset_index(drop=True)
display(df_shuffled.head())

print('\n')
print('\n')
print('Labels numbers :')
print('\n')
print(df_shuffled['Y'].value_counts())
# Out:
#                                                    X  Y
# 0  ..\files2\Viral Pneumonia\Viral Pneumonia (8).png  2
# 1                    ..\files2\COVID\COVID (544).png  0
# 2  ..\files2\Viral Pneumonia\Viral Pneumonia (743...  2
# 3                   ..\files2\COVID\COVID (1036).png  0
# 4  ..\files2\Viral Pneumonia\Viral Pneumonia (338...  2
# Labels numbers :
#
#
# 1    1194
# 0    1100
# 2    1067
# Name: Y, dtype: int64

# %%
X = df_shuffled['X']
Y = df_shuffled['Y'].values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=0,stratify=Y)

train_tensor = tf.data.Dataset.from_tensor_slices((X_train))
validation_tensor = tf.data.Dataset.from_tensor_slices((X_test))

label_train = tf.data.Dataset.from_tensor_slices(y_train) 
label_val= tf.data.Dataset.from_tensor_slices(y_test)

# %%
def data_aug(img, label):

    img= tf.io.read_file(img)
    img = tf.image.decode_jpeg(img, channels=3)
    #img = tf.image.central_crop(img, central_fraction=0.7)
    img = tf.image.resize(img, [256, 256])
    img = tf.image.random_flip_left_right(img)
    #img = tf.image.random_contrast(img, 0.5, 0.7)
    img = tf.image.random_brightness(img, 0.05)
    #img = tf.image.random_crop(img, [256,256,3])
    img = img / 255

    return img, label

def load_and_preprocess_images(img):
    img = tf.io.read_file(img)
    img = tf.image.decode_jpeg(img, channels=3)
    #img = tf.image.central_crop(img, central_fraction=0.7)
    img = tf.image.resize(img, [256, 256])
    img = img / 255
    return img

# %%
train_data = tf.data.Dataset.zip((train_tensor, label_train))
repeated_train_data= train_data.repeat(2)
repeated_train_data= repeated_train_data.map(data_aug)

# %%
#train_tensor = train_tensor.map(load_and_preprocess_images)
#train_data = tf.data.Dataset.zip((train_tensor, label_train))

# %%
validation_tensor = validation_tensor.map(load_and_preprocess_images)
validation_data = tf.data.Dataset.zip((validation_tensor, label_val))

# %%
print('size of train set is {} total images'.format(len(repeated_train_data)))
print('size of validation set is {} images total'.format(len(validation_data)))
# Out:
# size of train set is 4704 total images
# size of validation set is 1009 images total

# %%
repeated_train_data = repeated_train_data.shuffle(len(repeated_train_data)).batch(10)
validation_data = validation_data.batch(10)

# %%
#train_data = train_data.shuffle(len(train_data)).batch(16)
#validation_data = validation_data.batch(16)

# %%
for tensor,label in repeated_train_data.take(1):
#for tensor,label in train_data.take(1):
    print (tensor)
    print(label)
# Out:
# tf.Tensor(
# [[[[ 6.6688204e-01  6.6688204e-01  6.6688204e-01]
#    [ 5.9620827e-01  5.9620827e-01  5.9620827e-01]
#    [ 5.7566530e-01  5.7566530e-01  5.7566530e-01]
#    ...
#    [ 5.7610679e-01  5.7610679e-01  5.7610679e-01]
#    [ 5.7841760e-01  5.7841760e-01  5.7841760e-01]
#    [ 5.8055484e-01  5.8055484e-01  5.8055484e-01]]
#
#   [[ 6.7186028e-01  6.7186028e-01  6.7186028e-01]
#    [ 6.2480813e-01  6.2480813e-01  6.2480813e-01]
#    [ 5.7655650e-01  5.7655650e-01  5.7655650e-01]
#    ...
#    [ 5.8013976e-01  5.8013976e-01  5.8013976e-01]
#    [ 5.9319818e-01  5.9319818e-01  5.9319818e-01]
#    [ 5.8478057e-01  5.8478057e-01  5.8478057e-01]]
#
#   [[ 6.5091664e-01  6.5091664e-01  6.5091664e-01]
#    [ 6.6405803e-01  6.6405803e-01  6.6405803e-01]
#    [ 5.9749925e-01  5.9749925e-01  5.9749925e-01]
#    ...
#    [ 5.8461553e-01  5.8461553e-01  5.8461553e-01]
#    [ 6.1505920e-01  6.1505920e-01  6.1505920e-01]
#    [ 5.8480221e-01  5.8480221e-01  5.8480221e-01]]
#
#   ...
#
#   [[ 6.1952323e-01  6.1952323e-01  6.1952323e-01]
#    [ 6.1686122e-01  6.1686122e-01  6.1686122e-01]
#    [ 6.3111311e-01  6.3111311e-01  6.3111311e-01]
#    ...
#    [ 1.6197328e-01  1.6197328e-01  1.6197328e-01]
#    [ 1.4270800e-01  1.4270800e-01  1.4270800e-01]
#    [ 8.0985077e-02  8.0985077e-02  8.0985077e-02]]
#
#   [[ 6.2256491e-01  6.2256491e-01  6.2256491e-01]
#    [ 6.1535364e-01  6.1535364e-01  6.1535364e-01]
#    [ 6.2938559e-01  6.2938559e-01  6.2938559e-01]
#    ...
#    [ 1.5945126e-01  1.5945126e-01  1.5945126e-01]
#    [ 1.3613631e-01  1.3613631e-01  1.3613631e-01]
#    [ 7.5398922e-02  7.5398922e-02  7.5398922e-02]]
#
#   [[ 6.1314625e-01  6.1314625e-01  6.1314625e-01]
#    [ 6.3014096e-01  6.3014096e-01  6.3014096e-01]
#    [ 6.2308830e-01  6.2308830e-01  6.2308830e-01]
#    ...
#    [ 1.4860916e-01  1.4860916e-01  1.4860916e-01]
#    [ 1.3606167e-01  1.3606167e-01  1.3606167e-01]
#    [ 6.9252945e-02  6.9252945e-02  6.9252945e-02]]]
#
#
#  [[[ 6.9655037e-01  6.9655037e-01  6.9655037e-01]
#    [ 6.4746928e-01  6.4746928e-01  6.4746928e-01]
#    [ 6.9667733e-01  6.9667733e-01  6.9667733e-01]
#    ...
#    [ 6.1300236e-01  6.1300236e-01  6.1300236e-01]
#    [ 5.8525294e-01  5.8525294e-01  5.8525294e-01]
#    [ 6.3019067e-01  6.3019067e-01  6.3019067e-01]]
#
#   [[ 6.5816754e-01  6.5816754e-01  6.5816754e-01]
#    [ 6.7842084e-01  6.7842084e-01  6.7842084e-01]
#    [ 6.5948147e-01  6.5948147e-01  6.5948147e-01]
#    ...
#    [ 5.6441134e-01  5.6441134e-01  5.6441134e-01]
#    [ 6.0016561e-01  6.0016561e-01  6.0016561e-01]
#    [ 5.8483785e-01  5.8483785e-01  5.8483785e-01]]
#
#   [[ 6.5493947e-01  6.5493947e-01  6.5493947e-01]
#    [ 6.4564604e-01  6.4564604e-01  6.4564604e-01]
#    [ 7.1135670e-01  7.1135670e-01  7.1135670e-01]
#    ...
#    [ 5.9603810e-01  5.9603810e-01  5.9603810e-01]
#    [ 5.8069235e-01  5.8069235e-01  5.8069235e-01]
#    [ 5.9703350e-01  5.9703350e-01  5.9703350e-01]]
#
#   ...
#
#   [[ 4.3580648e-01  4.3580648e-01  4.3580648e-01]
#    [ 6.9871247e-01  6.9871247e-01  6.9871247e-01]
#    [ 6.9893914e-01  6.9893914e-01  6.9893914e-01]
#    ...
#    [ 4.0746391e-01  4.0746391e-01  4.0746391e-01]
#    [ 4.4522977e-01  4.4522977e-01  4.4522977e-01]
#    [ 5.0387979e-01  5.0387979e-01  5.0387979e-01]]
#
#   [[ 4.4184056e-01  4.4184056e-01  4.4184056e-01]
#    [ 6.9045871e-01  6.9045871e-01  6.9045871e-01]
#    [ 6.8251526e-01  6.8251526e-01  6.8251526e-01]
#    ...
#    [ 4.5342290e-01  4.5342290e-01  4.5342290e-01]
#    [ 4.6647266e-01  4.6647266e-01  4.6647266e-01]
#    [ 5.2730674e-01  5.2730674e-01  5.2730674e-01]]
#
#   [[ 4.7149321e-01  4.7149321e-01  4.7149321e-01]
#    [ 6.9185293e-01  6.9185293e-01  6.9185293e-01]
#    [ 6.9623423e-01  6.9623423e-01  6.9623423e-01]
#    ...
#    [ 4.5368600e-01  4.5368600e-01  4.5368600e-01]
#    [ 4.8706675e-01  4.8706675e-01  4.8706675e-01]
#    [ 5.5063128e-01  5.5063128e-01  5.5063128e-01]]]
#
#
#  [[[ 2.4197979e-01  2.4197979e-01  2.4197979e-01]
#    [ 2.4001135e-01  2.4001135e-01  2.4001135e-01]
#    [ 2.4613114e-01  2.4613114e-01  2.4613114e-01]
#    ...
#    [ 2.5019056e-01  2.5019056e-01  2.5019056e-01]
#    [ 2.5875369e-01  2.5875369e-01  2.5875369e-01]
#    [ 2.9152790e-01  2.9152790e-01  2.9152790e-01]]
#
#   [[ 2.2437869e-01  2.2437869e-01  2.2437869e-01]
#    [ 2.4865870e-01  2.4865870e-01  2.4865870e-01]
#    [ 2.3504044e-01  2.3504044e-01  2.3504044e-01]
#    ...
#    [ 2.7516761e-01  2.7516761e-01  2.7516761e-01]
#    [ 2.8683275e-01  2.8683275e-01  2.8683275e-01]
#    [ 2.5117096e-01  2.5117096e-01  2.5117096e-01]]
#
#   [[ 2.2586459e-01  2.2586459e-01  2.2586459e-01]
#    [ 2.1693383e-01  2.1693383e-01  2.1693383e-01]
#    [ 2.2051074e-01  2.2051074e-01  2.2051074e-01]
#    ...
#    [ 2.7139923e-01  2.7139923e-01  2.7139923e-01]
#    [ 2.5150800e-01  2.5150800e-01  2.5150800e-01]
#    [ 2.5742865e-01  2.5742865e-01  2.5742865e-01]]
#
#   ...
#
#   [[ 2.5326198e-01  2.5326198e-01  2.5326198e-01]
#    [ 2.4667494e-01  2.4667494e-01  2.4667494e-01]
#    [ 2.7826962e-01  2.7826962e-01  2.7826962e-01]
#    ...
#    [ 1.9670558e-01  1.9670558e-01  1.9670558e-01]
#    [ 1.6387777e-01  1.6387777e-01  1.6387777e-01]
#    [ 1.3690932e-01  1.3690932e-01  1.3690932e-01]]
#
#   [[ 2.4328187e-01  2.4328187e-01  2.4328187e-01]
#    [ 2.4561030e-01  2.4561030e-01  2.4561030e-01]
#    [ 2.8648809e-01  2.8648809e-01  2.8648809e-01]
#    ...
#    [ 1.9622305e-01  1.9622305e-01  1.9622305e-01]
#    [ 1.7435570e-01  1.7435570e-01  1.7435570e-01]
#    [ 1.3690932e-01  1.3690932e-01  1.3690932e-01]]
#
#   [[ 2.3648040e-01  2.3648040e-01  2.3648040e-01]
#    [ 2.3719272e-01  2.3719272e-01  2.3719272e-01]
#    [ 3.1096724e-01  3.1096724e-01  3.1096724e-01]
#    ...
#    [ 1.9661367e-01  1.9661367e-01  1.9661367e-01]
#    [ 1.7175154e-01  1.7175154e-01  1.7175154e-01]
#    [ 1.3004658e-01  1.3004658e-01  1.3004658e-01]]]
#
#
#  ...
#
#
#  [[[ 5.2011764e-01  5.2011764e-01  5.2011764e-01]
#    [ 5.0304216e-01  5.0304216e-01  5.0304216e-01]
#    [ 4.9850643e-01  4.9850643e-01  4.9850643e-01]
#    ...
#    [ 4.1100836e-01  4.1100836e-01  4.1100836e-01]
#    [ 4.0499818e-01  4.0499818e-01  4.0499818e-01]
#    [ 4.0094832e-01  4.0094832e-01  4.0094832e-01]]
#
#   [[ 5.7455671e-01  5.7455671e-01  5.7455671e-01]
#    [ 5.3503466e-01  5.3503466e-01  5.3503466e-01]
#    [ 5.1126206e-01  5.1126206e-01  5.1126206e-01]
#    ...
#    [ 4.1443494e-01  4.1443494e-01  4.1443494e-01]
#    [ 4.0852818e-01  4.0852818e-01  4.0852818e-01]
#    [ 4.1315535e-01  4.1315535e-01  4.1315535e-01]]
#
#   [[ 6.3487428e-01  6.3487428e-01  6.3487428e-01]
#    [ 6.0182911e-01  6.0182911e-01  6.0182911e-01]
#    [ 5.6180924e-01  5.6180924e-01  5.6180924e-01]
#    ...
#    [ 4.6034199e-01  4.6034199e-01  4.6034199e-01]
#    [ 4.2172563e-01  4.2172563e-01  4.2172563e-01]
#    [ 4.2438102e-01  4.2438102e-01  4.2438102e-01]]
#
#   ...
#
#   [[ 8.4706837e-01  8.4706837e-01  8.4706837e-01]
#    [ 8.4238666e-01  8.4238666e-01  8.4238666e-01]
#    [ 8.2342505e-01  8.2342505e-01  8.2342505e-01]
#    ...
#    [ 7.7991682e-01  7.7991682e-01  7.7991682e-01]
#    [ 7.8014851e-01  7.8014851e-01  7.8014851e-01]
#    [ 7.8948760e-01  7.8948760e-01  7.8948760e-01]]
#
#   [[ 8.5340023e-01  8.5340023e-01  8.5340023e-01]
#    [ 8.4797317e-01  8.4797317e-01  8.4797317e-01]
#    [ 8.3212936e-01  8.3212936e-01  8.3212936e-01]
#    ...
#    [ 7.7901393e-01  7.7901393e-01  7.7901393e-01]
#    [ 7.8238070e-01  7.8238070e-01  7.8238070e-01]
#    [ 7.9502720e-01  7.9502720e-01  7.9502720e-01]]
#
#   [[ 8.0695468e-01  8.0695468e-01  8.0695468e-01]
#    [ 7.9841262e-01  7.9841262e-01  7.9841262e-01]
#    [ 7.8690737e-01  7.8690737e-01  7.8690737e-01]
#    ...
#    [ 7.3686093e-01  7.3686093e-01  7.3686093e-01]
#    [ 7.4319041e-01  7.4319041e-01  7.4319041e-01]
#    [ 7.5534570e-01  7.5534570e-01  7.5534570e-01]]]
#
#
#  [[[ 1.7073722e-01  1.7073722e-01  1.7073722e-01]
#    [ 1.7553419e-01  1.7553419e-01  1.7553419e-01]
#    [ 1.7642044e-01  1.7642044e-01  1.7642044e-01]
#    ...
#    [ 2.3548687e-03  2.3548687e-03  2.3548687e-03]
#    [ 2.3548687e-03  2.3548687e-03  2.3548687e-03]
#    [ 3.3972115e-04  3.3972115e-04  3.3972115e-04]]
#
#   [[ 1.4961283e-01  1.4961283e-01  1.4961283e-01]
#    [ 1.5638274e-01  1.5638274e-01  1.5638274e-01]
#    [ 1.6920125e-01  1.6920125e-01  1.6920125e-01]
#    ...
#    [-5.0155875e-05 -5.0155875e-05 -5.0155875e-05]
#    [-5.0155875e-05 -5.0155875e-05 -5.0155875e-05]
#    [-5.0155875e-05 -5.0155875e-05 -5.0155875e-05]]
#
#   [[ 1.4875124e-01  1.4875124e-01  1.4875124e-01]
#    [ 1.5466441e-01  1.5466441e-01  1.5466441e-01]
#    [ 1.5781596e-01  1.5781596e-01  1.5781596e-01]
#    ...
#    [-5.0155875e-05 -5.0155875e-05 -5.0155875e-05]
#    [-5.0155875e-05 -5.0155875e-05 -5.0155875e-05]
#    [-5.0155875e-05 -5.0155875e-05 -5.0155875e-05]]
#
#   ...
#
#   [[ 2.3471920e-01  2.3471920e-01  2.3471920e-01]
#    [ 2.9636887e-01  2.9636887e-01  2.9636887e-01]
#    [ 4.0439227e-01  4.0439227e-01  4.0439227e-01]
#    ...
#    [ 8.0816872e-02  8.0816872e-02  8.0816872e-02]
#    [ 5.4744575e-02  5.4744575e-02  5.4744575e-02]
#    [ 3.9801255e-02  3.9801255e-02  3.9801255e-02]]
#
#   [[ 2.5551051e-01  2.5551051e-01  2.5551051e-01]
#    [ 3.2368121e-01  3.2368121e-01  3.2368121e-01]
#    [ 4.2552483e-01  4.2552483e-01  4.2552483e-01]
#    ...
#    [ 8.0816872e-02  8.0816872e-02  8.0816872e-02]
#    [ 5.4744575e-02  5.4744575e-02  5.4744575e-02]
#    [ 3.9801255e-02  3.9801255e-02  3.9801255e-02]]
#
#   [[ 2.7485028e-01  2.7485028e-01  2.7485028e-01]
#    [ 3.5465267e-01  3.5465267e-01  3.5465267e-01]
#    [ 4.1289392e-01  4.1289392e-01  4.1289392e-01]
#    ...
#    [ 8.0816872e-02  8.0816872e-02  8.0816872e-02]
#    [ 5.4744575e-02  5.4744575e-02  5.4744575e-02]
#    [ 4.3087099e-02  4.3087099e-02  4.3087099e-02]]]
#
#
#  [[[ 5.2306652e-01  5.2306652e-01  5.2306652e-01]
#    [ 5.2577937e-01  5.2577937e-01  5.2577937e-01]
#    [ 5.3179342e-01  5.3179342e-01  5.3179342e-01]
#    ...
#    [ 5.7788366e-01  5.7788366e-01  5.7788366e-01]
#    [ 5.4901123e-01  5.4901123e-01  5.4901123e-01]
#    [ 5.3600842e-01  5.3600842e-01  5.3600842e-01]]
#
#   [[ 5.1976144e-01  5.1976144e-01  5.1976144e-01]
#    [ 5.3394735e-01  5.3394735e-01  5.3394735e-01]
#    [ 5.5654883e-01  5.5654883e-01  5.5654883e-01]
#    ...
#    [ 5.9827334e-01  5.9827334e-01  5.9827334e-01]
#    [ 5.7305664e-01  5.7305664e-01  5.7305664e-01]
#    [ 5.6208628e-01  5.6208628e-01  5.6208628e-01]]
#
#   [[ 5.3050452e-01  5.3050452e-01  5.3050452e-01]
#    [ 5.3623527e-01  5.3623527e-01  5.3623527e-01]
#    [ 5.2386814e-01  5.2386814e-01  5.2386814e-01]
#    ...
#    [ 5.9240758e-01  5.9240758e-01  5.9240758e-01]
#    [ 5.8209014e-01  5.8209014e-01  5.8209014e-01]
#    [ 5.8570665e-01  5.8570665e-01  5.8570665e-01]]
#
#   ...
#
#   [[ 7.7417094e-01  7.7417094e-01  7.7417094e-01]
#    [ 7.7514851e-01  7.7514851e-01  7.7514851e-01]
#    [ 7.0516962e-01  7.0516962e-01  7.0516962e-01]
#    ...
#    [ 5.7874936e-01  5.7874936e-01  5.7874936e-01]
#    [ 3.9867935e-01  3.9867935e-01  3.9867935e-01]
#    [ 3.6036119e-01  3.6036119e-01  3.6036119e-01]]
#
#   [[ 8.1842703e-01  8.1842703e-01  8.1842703e-01]
#    [ 8.1011415e-01  8.1011415e-01  8.1011415e-01]
#    [ 7.4702239e-01  7.4702239e-01  7.4702239e-01]
#    ...
#    [ 6.1931640e-01  6.1931640e-01  6.1931640e-01]
#    [ 4.4929662e-01  4.4929662e-01  4.4929662e-01]
#    [ 3.9488286e-01  3.9488286e-01  3.9488286e-01]]
#
#   [[ 8.4148771e-01  8.4148771e-01  8.4148771e-01]
#    [ 8.5950482e-01  8.5950482e-01  8.5950482e-01]
#    [ 8.0979520e-01  8.0979520e-01  8.0979520e-01]
#    ...
#    [ 6.6870707e-01  6.6870707e-01  6.6870707e-01]
#    [ 4.9462217e-01  4.9462217e-01  4.9462217e-01]
#    [ 4.3577623e-01  4.3577623e-01  4.3577623e-01]]]], shape=(10, 256, 256, 3), dtype=float32)
# tf.Tensor([2 1 2 1 0 1 0 0 2 1], shape=(10,), dtype=int64)

# %%
for tensor,label in validation_data.take(1):
    print (tensor)
    print(label)
# Out:
# tf.Tensor(
# [[[[0.47548074 0.47548074 0.47548074]
#    [0.48516122 0.48516122 0.48516122]
#    [0.44823387 0.44823387 0.44823387]
#    ...
#    [0.19999775 0.19999775 0.19999775]
#    [0.17066751 0.17066751 0.17066751]
#    [0.14282367 0.14282367 0.14282367]]
#
#   [[0.45506054 0.45506054 0.45506054]
#    [0.46901724 0.46901724 0.46901724]
#    [0.45550704 0.45550704 0.45550704]
#    ...
#    [0.18061915 0.18061915 0.18061915]
#    [0.16170748 0.16170748 0.16170748]
#    [0.14479032 0.14479032 0.14479032]]
#
#   [[0.42953882 0.42953882 0.42953882]
#    [0.45275456 0.45275456 0.45275456]
#    [0.45535386 0.45535386 0.45535386]
#    ...
#    [0.18330377 0.18330377 0.18330377]
#    [0.16078432 0.16078432 0.16078432]
#    [0.13588388 0.13588388 0.13588388]]
#
#   ...
#
#   [[0.35277134 0.35277134 0.35277134]
#    [0.56822914 0.56822914 0.56822914]
#    [0.5478743  0.5478743  0.5478743 ]
#    ...
#    [0.2902798  0.2902798  0.2902798 ]
#    [0.1655187  0.1655187  0.1655187 ]
#    [0.13566943 0.13566943 0.13566943]]
#
#   [[0.35942996 0.35942996 0.35942996]
#    [0.58274275 0.58274275 0.58274275]
#    [0.5285836  0.5285836  0.5285836 ]
#    ...
#    [0.2714029  0.2714029  0.2714029 ]
#    [0.15681636 0.15681636 0.15681636]
#    [0.14003523 0.14003523 0.14003523]]
#
#   [[0.3386728  0.3386728  0.3386728 ]
#    [0.59210455 0.59210455 0.59210455]
#    [0.5351572  0.5351572  0.5351572 ]
#    ...
#    [0.2865286  0.2865286  0.2865286 ]
#    [0.16269149 0.16269149 0.16269149]
#    [0.13352571 0.13352571 0.13352571]]]
#
#
#  [[[0.42647058 0.42647058 0.42647058]
#    [0.40980393 0.40980393 0.40980393]
#    [0.4019608  0.4019608  0.4019608 ]
#    ...
#    [0.44705883 0.44705883 0.44705883]
#    [0.44117647 0.44117647 0.44117647]
#    [0.44411764 0.44411764 0.44411764]]
#
#   [[0.44313726 0.44313726 0.44313726]
#    [0.4254902  0.4254902  0.4254902 ]
#    [0.40882352 0.40882352 0.40882352]
#    ...
#    [0.45392156 0.45392156 0.45392156]
#    [0.44705883 0.44705883 0.44705883]
#    [0.4372549  0.4372549  0.4372549 ]]
#
#   [[0.4490196  0.4490196  0.4490196 ]
#    [0.44019607 0.44019607 0.44019607]
#    [0.42156863 0.42156863 0.42156863]
#    ...
#    [0.45588234 0.45588234 0.45588234]
#    [0.44313726 0.44313726 0.44313726]
#    [0.44607842 0.44607842 0.44607842]]
#
#   ...
#
#   [[0.3617647  0.3617647  0.3617647 ]
#    [0.43529412 0.43529412 0.43529412]
#    [0.47941175 0.47941175 0.47941175]
#    ...
#    [0.61960787 0.61960787 0.61960787]
#    [0.6068627  0.6068627  0.6068627 ]
#    [0.5901961  0.5901961  0.5901961 ]]
#
#   [[0.3754902  0.3754902  0.3754902 ]
#    [0.4245098  0.4245098  0.4245098 ]
#    [0.4852941  0.4852941  0.4852941 ]
#    ...
#    [0.61764705 0.61764705 0.61764705]
#    [0.6098039  0.6098039  0.6098039 ]
#    [0.59705883 0.59705883 0.59705883]]
#
#   [[0.36666667 0.36666667 0.36666667]
#    [0.42941177 0.42941177 0.42941177]
#    [0.49215686 0.49215686 0.49215686]
#    ...
#    [0.6382353  0.6382353  0.6382353 ]
#    [0.6137255  0.6137255  0.6137255 ]
#    [0.59313726 0.59313726 0.59313726]]]
#
#
#  [[[0.6306356  0.6306356  0.6306356 ]
#    [0.63572645 0.63572645 0.63572645]
#    [0.60493505 0.60493505 0.60493505]
#    ...
#    [0.60270375 0.60270375 0.60270375]
#    [0.5952381  0.5952381  0.5952381 ]
#    [0.5529883  0.5529883  0.5529883 ]]
#
#   [[0.60468966 0.60468966 0.60468966]
#    [0.6218947  0.6218947  0.6218947 ]
#    [0.5679567  0.5679567  0.5679567 ]
#    ...
#    [0.6003247  0.6003247  0.6003247 ]
#    [0.66832876 0.66832876 0.66832876]
#    [0.6033429  0.6033429  0.6033429 ]]
#
#   [[0.606587   0.606587   0.606587  ]
#    [0.6067355  0.6067355  0.6067355 ]
#    [0.58678246 0.58678246 0.58678246]
#    ...
#    [0.6275965  0.6275965  0.6275965 ]
#    [0.6490811  0.6490811  0.6490811 ]
#    [0.6145895  0.6145895  0.6145895 ]]
#
#   ...
#
#   [[0.4392157  0.4392157  0.4392157 ]
#    [0.48362288 0.48362288 0.48362288]
#    [0.5998134  0.5998134  0.5998134 ]
#    ...
#    [0.7416516  0.7416516  0.7416516 ]
#    [0.550337   0.550337   0.550337  ]
#    [0.55770624 0.55770624 0.55770624]]
#
#   [[0.43356523 0.43356523 0.43356523]
#    [0.48204786 0.48204786 0.48204786]
#    [0.59607846 0.59607846 0.59607846]
#    ...
#    [0.74852496 0.74852496 0.74852496]
#    [0.5542586  0.5542586  0.5542586 ]
#    [0.5604626  0.5604626  0.5604626 ]]
#
#   [[0.42781702 0.42781702 0.42781702]
#    [0.45330116 0.45330116 0.45330116]
#    [0.60041314 0.60041314 0.60041314]
#    ...
#    [0.72549117 0.72549117 0.72549117]
#    [0.566148   0.566148   0.566148  ]
#    [0.57109535 0.57109535 0.57109535]]]
#
#
#  ...
#
#
#  [[[0.51161486 0.51161486 0.51161486]
#    [0.53024924 0.53024924 0.53024924]
#    [0.56136644 0.56136644 0.56136644]
#    ...
#    [0.40823448 0.40823448 0.40823448]
#    [0.37623578 0.37623578 0.37623578]
#    [0.3739107  0.3739107  0.3739107 ]]
#
#   [[0.5275735  0.5275735  0.5275735 ]
#    [0.5226716  0.5226716  0.5226716 ]
#    [0.5649608  0.5649608  0.5649608 ]
#    ...
#    [0.41025367 0.41025367 0.41025367]
#    [0.38658136 0.38658136 0.38658136]
#    [0.37465295 0.37465295 0.37465295]]
#
#   [[0.5146446  0.5146446  0.5146446 ]
#    [0.5355797  0.5355797  0.5355797 ]
#    [0.54445875 0.54445875 0.54445875]
#    ...
#    [0.3981699  0.3981699  0.3981699 ]
#    [0.38911277 0.38911277 0.38911277]
#    [0.38522878 0.38522878 0.38522878]]
#
#   ...
#
#   [[0.55810213 0.55810213 0.55810213]
#    [0.5816275  0.5816275  0.5816275 ]
#    [0.59997344 0.59997344 0.59997344]
#    ...
#    [0.61611927 0.61611927 0.61611927]
#    [0.615799   0.615799   0.615799  ]
#    [0.6168129  0.6168129  0.6168129 ]]
#
#   [[0.55871105 0.55871105 0.55871105]
#    [0.58618283 0.58618283 0.58618283]
#    [0.5766446  0.5766446  0.5766446 ]
#    ...
#    [0.6208432  0.6208432  0.6208432 ]
#    [0.6130821  0.6130821  0.6130821 ]
#    [0.608027   0.608027   0.608027  ]]
#
#   [[0.5428785  0.5428785  0.5428785 ]
#    [0.5726206  0.5726206  0.5726206 ]
#    [0.5706426  0.5706426  0.5706426 ]
#    ...
#    [0.61302084 0.61302084 0.61302084]
#    [0.60389096 0.60389096 0.60389096]
#    [0.6044118  0.6044118  0.6044118 ]]]
#
#
#  [[[0.58723    0.58723    0.58723   ]
#    [0.58952206 0.58952206 0.58952206]
#    [0.60160846 0.60160846 0.60160846]
#    ...
#    [0.5812309  0.5812309  0.5812309 ]
#    [0.6129117  0.6129117  0.6129117 ]
#    [0.6111041  0.6111041  0.6111041 ]]
#
#   [[0.6220435  0.6220435  0.6220435 ]
#    [0.57942516 0.57942516 0.57942516]
#    [0.60498816 0.60498816 0.60498816]
#    ...
#    [0.6185834  0.6185834  0.6185834 ]
#    [0.6264591  0.6264591  0.6264591 ]
#    [0.6096871  0.6096871  0.6096871 ]]
#
#   [[0.5939894  0.5939894  0.5939894 ]
#    [0.5978535  0.5978535  0.5978535 ]
#    [0.606834   0.606834   0.606834  ]
#    ...
#    [0.62468594 0.62468594 0.62468594]
#    [0.61554265 0.61554265 0.61554265]
#    [0.6214499  0.6214499  0.6214499 ]]
#
#   ...
#
#   [[0.         0.         0.        ]
#    [0.         0.         0.        ]
#    [0.11357805 0.11357805 0.11357805]
#    ...
#    [0.56549096 0.56549096 0.56549096]
#    [0.59379405 0.59379405 0.59379405]
#    [0.6040977  0.6040977  0.6040977 ]]
#
#   [[0.         0.         0.        ]
#    [0.         0.         0.        ]
#    [0.11273361 0.11273361 0.11273361]
#    ...
#    [0.55491155 0.55491155 0.55491155]
#    [0.5808632  0.5808632  0.5808632 ]
#    [0.62454045 0.62454045 0.62454045]]
#
#   [[0.         0.         0.        ]
#    [0.         0.         0.        ]
#    [0.10048637 0.10048637 0.10048637]
#    ...
#    [0.57632124 0.57632124 0.57632124]
#    [0.5950942  0.5950942  0.5950942 ]
#    [0.6279412  0.6279412  0.6279412 ]]]
#
#
#  [[[0.32139164 0.32139164 0.32139164]
#    [0.32210758 0.32210758 0.32210758]
#    [0.30717275 0.30717275 0.30717275]
#    ...
#    [0.2258155  0.2258155  0.2258155 ]
#    [0.22406033 0.22406033 0.22406033]
#    [0.21176471 0.21176471 0.21176471]]
#
#   [[0.31647798 0.31647798 0.31647798]
#    [0.31624463 0.31624463 0.31624463]
#    [0.31107983 0.31107983 0.31107983]
#    ...
#    [0.2310815  0.2310815  0.2310815 ]
#    [0.22432637 0.22432637 0.22432637]
#    [0.21049568 0.21049568 0.21049568]]
#
#   [[0.3075372  0.3075372  0.3075372 ]
#    [0.3109911  0.3109911  0.3109911 ]
#    [0.31898257 0.31898257 0.31898257]
#    ...
#    [0.23534773 0.23534773 0.23534773]
#    [0.23137255 0.23137255 0.23137255]
#    [0.21623008 0.21623008 0.21623008]]
#
#   ...
#
#   [[0.27755418 0.27755418 0.27755418]
#    [0.30912864 0.30912864 0.30912864]
#    [0.31400055 0.31400055 0.31400055]
#    ...
#    [0.27517685 0.27517685 0.27517685]
#    [0.25475642 0.25475642 0.25475642]
#    [0.22808309 0.22808309 0.22808309]]
#
#   [[0.28248557 0.28248557 0.28248557]
#    [0.30245903 0.30245903 0.30245903]
#    [0.31209084 0.31209084 0.31209084]
#    ...
#    [0.26521015 0.26521015 0.26521015]
#    [0.2509804  0.2509804  0.2509804 ]
#    [0.23163821 0.23163821 0.23163821]]
#
#   [[0.27868575 0.27868575 0.27868575]
#    [0.302326   0.302326   0.302326  ]
#    [0.31421164 0.31421164 0.31421164]
#    ...
#    [0.26058155 0.26058155 0.26058155]
#    [0.24816419 0.24816419 0.24816419]
#    [0.22460172 0.22460172 0.22460172]]]], shape=(10, 256, 256, 3), dtype=float32)
# tf.Tensor([1 2 1 2 1 2 2 2 1 2], shape=(10,), dtype=int64)

# %%
def build_model_2():
    # we will use costum training with VGG19
    input_tensor = tf.keras.Input(shape=(256,256,3))
    VGG19 = tf.keras.applications.VGG16(input_shape=(256,256,3),include_top=False, input_tensor=input_tensor)
    VGG19.trainable = False # The VGG19 will use imagnet weight by default
    
    top_model = tf.keras.Sequential()
    top_model.add(tf.keras.layers.GlobalMaxPooling2D())
    top_model.add(tf.keras.layers.Dense(4096, activation=tf.nn.relu))
    top_model.add(tf.keras.layers.Dropout(0.3))
    top_model.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
    top_model.add(tf.keras.layers.Dense(512, activation=tf.nn.relu))
    top_model.add(tf.keras.layers.Dropout(0.1))
   
    top_model.add(tf.keras.layers.Dense(3, activation=tf.nn.softmax))
    
    model = tf.keras.Model(inputs=VGG19.input, outputs=top_model(VGG19.output))
    
    model.compile(optimizer = 'Adam',
              loss= tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics = tf.keras.metrics.SparseCategoricalAccuracy())
    return model

# %%
model = build_model_2()

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 256, 256, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 256, 256, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 256, 256, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 128, 128, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 128, 128, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 128, 128, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 64, 64, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 64, 64, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 64, 64, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 32, 32, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 32, 32, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 32, 32, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 16, 16, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# sequential (Sequential)      (None, 3)                 4463107
# =================================================================
# Total params: 19,177,795
# Trainable params: 4,463,107
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#model.fit(x=repeated_train_data, validation_data=validation_data, epochs=3)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping
# checkpoint will be use to save model each time performance are better
checkpoint = ModelCheckpoint("model_VGG19_3.h5", monitor='val_sparse_categorical_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
#early stopping will stop training if the validation accuracy don't progress  
early = EarlyStopping(monitor='val_sparse_categorical_accuracy',min_delta=0, patience=20, verbose=1, mode='auto')
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
history = model.fit(x=repeated_train_data, validation_data=validation_data, epochs=25, callbacks=[checkpoint,early])
# Out:
# Epoch 1/25
# 471/471 [==============================] - 68s 62ms/step - loss: 0.6213 - sparse_categorical_accuracy: 0.7337 - val_loss: 0.5014 - val_sparse_categorical_accuracy: 0.7790
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.77899, saving model to model_VGG19_3.h5
# Epoch 2/25
# 471/471 [==============================] - 60s 56ms/step - loss: 0.2792 - sparse_categorical_accuracy: 0.8906 - val_loss: 0.2944 - val_sparse_categorical_accuracy: 0.8940
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.77899 to 0.89395, saving model to model_VGG19_3.h5
# Epoch 3/25
# 471/471 [==============================] - 60s 55ms/step - loss: 0.2612 - sparse_categorical_accuracy: 0.9033 - val_loss: 0.1802 - val_sparse_categorical_accuracy: 0.934628 - sparse_categorical_accuracy: 0.9 - ETA: 0s - loss: 0.2624 - sparse_categorical_accurac
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.89395 to 0.93459, saving model to model_VGG19_3.h5
# Epoch 4/25
# 471/471 [==============================] - 60s 55ms/step - loss: 0.2120 - sparse_categorical_accuracy: 0.9261 - val_loss: 0.2092 - val_sparse_categorical_accuracy: 0.9376
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.93459 to 0.93756, saving model to model_VGG19_3.h5
# Epoch 5/25
# 471/471 [==============================] - 60s 55ms/step - loss: 0.1811 - sparse_categorical_accuracy: 0.9403 - val_loss: 0.3112 - val_sparse_categorical_accuracy: 0.9019
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.93756
# Epoch 6/25
# 471/471 [==============================] - 61s 56ms/step - loss: 0.1862 - sparse_categorical_accuracy: 0.9358 - val_loss: 0.1910 - val_sparse_categorical_accuracy: 0.9395uracy: 0.935 - ETA: 0s - loss: 0.1867 - sparse_categorical_ac
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.93756 to 0.93954, saving model to model_VGG19_3.h5
# Epoch 7/25
# 471/471 [==============================] - 61s 56ms/step - loss: 0.1724 - sparse_categorical_accuracy: 0.9450 - val_loss: 0.1686 - val_sparse_categorical_accuracy: 0.9475
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.93954 to 0.94747, saving model to model_VGG19_3.h5
# Epoch 8/25
# 471/471 [==============================] - 62s 57ms/step - loss: 0.1559 - sparse_categorical_accuracy: 0.9446 - val_loss: 0.3009 - val_sparse_categorical_accuracy: 0.8880categori - ETA: 2s - loss: 0.1544 -
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.94747
# Epoch 9/25
# 471/471 [==============================] - 63s 57ms/step - loss: 0.1688 - sparse_categorical_accuracy: 0.9396 - val_loss: 0.2065 - val_sparse_categorical_accuracy: 0.9306
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.94747
# Epoch 10/25
# 471/471 [==============================] - 64s 58ms/step - loss: 0.1550 - sparse_categorical_accuracy: 0.9470 - val_loss: 0.1870 - val_sparse_categorical_accuracy: 0.9544
#
# Epoch 00010: val_sparse_categorical_accuracy improved from 0.94747 to 0.95441, saving model to model_VGG19_3.h5
# Epoch 11/25
# 471/471 [==============================] - 64s 58ms/step - loss: 0.1521 - sparse_categorical_accuracy: 0.9507 - val_loss: 0.1448 - val_sparse_categorical_accuracy: 0.9544
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.95441
# Epoch 12/25
# 471/471 [==============================] - 65s 59ms/step - loss: 0.1515 - sparse_categorical_accuracy: 0.9449 - val_loss: 0.1386 - val_sparse_categorical_accuracy: 0.9534
#
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.95441
# Epoch 13/25
# 471/471 [==============================] - 66s 59ms/step - loss: 0.1252 - sparse_categorical_accuracy: 0.9588 - val_loss: 0.1429 - val_sparse_categorical_accuracy: 0.9574
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.95441 to 0.95738, saving model to model_VGG19_3.h5
# Epoch 14/25
# 471/471 [==============================] - 66s 59ms/step - loss: 0.1256 - sparse_categorical_accuracy: 0.9582 - val_loss: 0.1577 - val_sparse_categorical_accuracy: 0.9425
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 15/25
# 471/471 [==============================] - 67s 60ms/step - loss: 0.1364 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.1519 - val_sparse_categorical_accuracy: 0.9495
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 16/25
# 471/471 [==============================] - 68s 61ms/step - loss: 0.1182 - sparse_categorical_accuracy: 0.9609 - val_loss: 0.1494 - val_sparse_categorical_accuracy: 0.9504
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 17/25
# 471/471 [==============================] - 70s 63ms/step - loss: 0.1320 - sparse_categorical_accuracy: 0.9551 - val_loss: 0.2201 - val_sparse_categorical_accuracy: 0.9207
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 18/25
# 471/471 [==============================] - 71s 63ms/step - loss: 0.1252 - sparse_categorical_accuracy: 0.9601 - val_loss: 0.2104 - val_sparse_categorical_accuracy: 0.9366
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 19/25
# 471/471 [==============================] - 72s 64ms/step - loss: 0.1215 - sparse_categorical_accuracy: 0.9575 - val_loss: 0.1664 - val_sparse_categorical_accuracy: 0.9524
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 20/25
# 471/471 [==============================] - 73s 64ms/step - loss: 0.1221 - sparse_categorical_accuracy: 0.9638 - val_loss: 0.1594 - val_sparse_categorical_accuracy: 0.9524
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 21/25
# 471/471 [==============================] - 75s 65ms/step - loss: 0.1050 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.1788 - val_sparse_categorical_accuracy: 0.9495
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 22/25
# 471/471 [==============================] - 76s 66ms/step - loss: 0.1161 - sparse_categorical_accuracy: 0.9593 - val_loss: 0.1549 - val_sparse_categorical_accuracy: 0.9554
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 23/25
# 471/471 [==============================] - 76s 67ms/step - loss: 0.1023 - sparse_categorical_accuracy: 0.9652 - val_loss: 0.1499 - val_sparse_categorical_accuracy: 0.9564
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 24/25
# 471/471 [==============================] - 77s 67ms/step - loss: 0.0987 - sparse_categorical_accuracy: 0.9675 - val_loss: 0.1689 - val_sparse_categorical_accuracy: 0.9554
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.95738
# Epoch 25/25
# 471/471 [==============================] - 77s 68ms/step - loss: 0.1197 - sparse_categorical_accuracy: 0.9559 - val_loss: 0.1573 - val_sparse_categorical_accuracy: 0.9514
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.95738

# %% [markdown]
# ### The final accuracy for the model is 96% Epoch 20

# %%
loss_curve = history.history["loss"]
loss_val = history.history["val_loss"]
acc_curve = history.history["sparse_categorical_accuracy"]
acc_val = history.history["val_sparse_categorical_accuracy"]

plt.plot(loss_val,label="Loss_val")
plt.plot(loss_curve,label="Loss_train")
plt.legend()
plt.title("loss")
plt.show()

plt.plot(acc_val, label="acc_val" )
plt.plot(acc_curve, label="acc_train" )
plt.legend()
plt.title("accuracy")
plt.show()

# %% [markdown]
# # GRAD CAM

# %% [markdown]
# *We will use gradiant to visualize the model detection's result*

# %%
#for the prepocessing of image
img_size = (256, 256)
preprocess_input = tf.keras.applications.xception.preprocess_input

#we selected the last convolution layers
last_conv_layer_name = "block5_conv3"
classifier_layer_names = ["block5_pool","sequential"]

# %%
def get_img_array(img_path, size):
    
    img = tf.keras.preprocessing.image.load_img(img_path, target_size=size)
    array = tf.keras.preprocessing.image.img_to_array(img)
    array = np.expand_dims(array, axis=0)
    return array


def make_gradcam_heatmap(
    img_array, model, last_conv_layer_name, classifier_layer_names
):
    # First, we create a model that maps the input image to the activations
    # of the last conv layer
    last_conv_layer = model.get_layer(last_conv_layer_name)
    last_conv_layer_model = tf.keras.Model(model.inputs, last_conv_layer.output)

    # Second, we create a model that maps the activations of the last conv
    # layer to the final class predictions

    classifier_input = tf.keras.Input(shape=last_conv_layer.output.shape[1:])
    x = classifier_input
    for layer_name in classifier_layer_names:
        x = model.get_layer(layer_name)(x)
    classifier_model = tf.keras.Model(classifier_input, x)

    #classifier = model.get_layer(classifier_layer_names)
    #classifier_model = tf.keras.Model(classifier.input, classifier.output)

    # Then, we compute the gradient of the top predicted class for our input image
    # with respect to the activations of the last conv layer
    with tf.GradientTape() as tape:
        # Compute activations of the last conv layer and make the tape watch it
        last_conv_layer_output = last_conv_layer_model(img_array)
        tape.watch(last_conv_layer_output)
        # Compute class predictions
        preds = classifier_model(last_conv_layer_output)
        top_pred_index = tf.argmax(preds[0])
        top_class_channel = preds[:, top_pred_index]

    # This is the gradient of the top predicted class with regard to
    # the output feature map of the last conv layer
    grads = tape.gradient(top_class_channel, last_conv_layer_output)

    # This is a vector where each entry is the mean intensity of the gradient
    # over a specific feature map channel
    pooled_grads = tf.reduce_mean(grads, axis=(0, 1, 2))

    # We multiply each channel in the feature map array
    # by "how important this channel is" with regard to the top predicted class
    last_conv_layer_output = last_conv_layer_output.numpy()[0]
    pooled_grads = pooled_grads.numpy()
    for i in range(pooled_grads.shape[-1]):
        last_conv_layer_output[:, :, i] *= pooled_grads[i]

    # The channel-wise mean of the resulting feature map
    # is our heatmap of class activation
    heatmap = np.mean(last_conv_layer_output, axis=-1)

    # For visualization purpose, we will also normalize the heatmap between 0 & 1
    heatmap = np.maximum(heatmap, 0) / np.max(heatmap)
    return heatmap

# %%
import glob
from PIL import Image
covid = "../Images/Train/COVID/*"
pneumo = "../Images/Train/Viral Pneumonia/*"
normal = "../Images/Train/NORMAL/*"
path_covid = glob.glob(covid)[10]
path_pneumo = glob.glob(pneumo)[10]
path_normal = glob.glob(normal)[50]
img_covid = Image.open(glob.glob(covid)[10])
img_pneumo = Image.open(glob.glob(pneumo)[10])
img_normal = Image.open(glob.glob(normal)[10])

# %%
glob.glob(covid)[86]
# Out:
# '../Images/Train/COVID\\COVID (1086).png'

# %%
# Prepare image
img_array_c = preprocess_input(get_img_array(path_covid, size=img_size))
img_array_p = preprocess_input(get_img_array(path_pneumo, size=img_size))
img_array_n = preprocess_input(get_img_array(path_normal, size=img_size))

# Make model
model = tf.keras.models.load_model("model_VGG19_2.h5")
#9Generate class activation heatmap
heatmap_c = make_gradcam_heatmap(
    img_array_c, model, last_conv_layer_name, classifier_layer_names
)
heatmap_p = make_gradcam_heatmap(
    img_array_p, model, last_conv_layer_name, classifier_layer_names
)
heatmap_n = make_gradcam_heatmap(
    img_array_n, model, last_conv_layer_name, classifier_layer_names
)

# %%
def superpose(path, heatmap):
    # We load the original image
    img = tf.keras.preprocessing.image.load_img(path)
    img = tf.keras.preprocessing.image.img_to_array(img)
    # We rescale heatmap to a range 0-255
    heatmap = np.uint8(255 * heatmap)
    # We use jet colormap to colorize heatmap
    jet = cm.get_cmap("jet")
    # We use RGB values of the colormap
    jet_colors = jet(np.arange(256))[:, :3]
    jet_heatmap = jet_colors[heatmap]
    # We create an image with RGB colorized heatmap
    jet_heatmap = tf.keras.preprocessing.image.array_to_img(jet_heatmap)
    jet_heatmap = jet_heatmap.resize((img.shape[1], img.shape[0]))
    jet_heatmap = tf.keras.preprocessing.image.img_to_array(jet_heatmap)
    # Superimpose the heatmap on original image
    superimposed_img = jet_heatmap * 0.4 + img
    return  tf.keras.preprocessing.image.array_to_img(superimposed_img)
    
    

# Save the superimposed image
#save_path = "grad_cam_radio.jpg"
#superimposed_img.save(save_path)

# Display Grad CAM
#display(Image(save_path))
plt.figure(figsize=(20,20))

plt.subplot(2,3,1)
plt.imshow(superpose(path_covid,heatmap_c))
plt.title("COVID")

plt.subplot(2,3,2)
plt.imshow(superpose(path_pneumo,heatmap_p))
plt.title("Viral Pneumonia")

plt.subplot(2,3,3)
plt.imshow(superpose(path_normal,heatmap_n))
plt.title("Normal")

plt.subplot(2,3,4)
plt.imshow(img_covid,cmap='binary')
plt.title("COVID")

plt.subplot(2,3,5)
plt.imshow(img_pneumo,cmap='binary')
plt.title("Viral Pneumonia")

plt.subplot(2,3,6)
plt.imshow(img_normal,cmap='binary')
plt.title("Normal")

plt.show()

# %%
model = tf.keras.models.load_model(r'C:\Users\froge\Exo_jedha\PROJET\COVID-19 Radiography Database\Modeles\model_VGG19_2.h5')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-34-c520d16372b9> in <module>
# ----> 1 model = tf.keras.models.load_model(r'C:\Users\froge\Exo_jedha\PROJET\COVID-19 Radiography Database\Modeles\model_VGG19_2.h5')
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     210       filepath = path_to_string(filepath)
#     211       if isinstance(filepath, six.string_types):
# --> 212         loader_impl.parse_saved_model(filepath)
#     213         return saved_model_load.load(filepath, compile, options)
#     214
#
# ~\AppData\Roaming\Python\Python38\site-packages\tensorflow\python\saved_model\loader_impl.py in parse_saved_model(export_dir)
#     109       raise IOError("Cannot parse file %s: %s." % (path_to_pbtxt, str(e)))
#     110   else:
# --> 111     raise IOError("SavedModel file does not exist at: %s/{%s|%s}" %
#     112                   (export_dir,
#     113                    constants.SAVED_MODEL_FILENAME_PBTXT,
#
# OSError: SavedModel file does not exist at: C:\Users\froge\Exo_jedha\PROJET\COVID-19 Radiography Database\Modeles\model_VGG19_2.h5/{saved_model.pbtxt|saved_model.pb}

# %%
predictions = model.predict(validation_data)
labels = [0,1,2]

# %%
tf.math.confusion_matrix(labels, predictions)

# %%
img= tf.io.read_file(path_covid)
img = tf.image.decode_jpeg(img, channels=3)
img = tf.image.central_crop(img, central_fraction=0.7)
img = tf.image.resize(img, [256, 256])
img = img / 255

# %%
plt.imshow(img)

# %%
import cv2

# %%
img= tf.io.read_file(path_covid)
img = tf.image.decode_jpeg(img, channels=3)

# %%
img = cv2.imread(path_pneumo)
#resize = cv2.resize(img,None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
resize = img[100:2000,0:2560]
plt.subplot(121)
plt.imshow(img)
plt.subplot(122)
plt.imshow(resize)
